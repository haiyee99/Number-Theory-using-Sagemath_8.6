# %%
a = -5; b = 8;
# y^2 = x^3 + ax + b
# 4a^3 + 27b^2 != 0

E = EllipticCurve([a, b]);
E.plot().show();
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p = 5;

EG = EllipticCurve(GF(p), [a, b]);
EG.plot().show();
print(EG.cardinality());
# Out:
# Graphics object consisting of 1 graphics primitive
# 6

# %%
def f(x):
    return x**3 + a*x + b; 

s = 0;
for i in range(p):
    s += 1 + legendre_symbol(f(i), p);
    
print(s + 1);
# Out:
# 6
